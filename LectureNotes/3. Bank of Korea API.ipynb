# %% [markdown]
# # Guide to Bank of Korea API
#
# ### week 2-1
#
# In this note, we learn how to download data of interest using Bank of Korea API. BOK API is constructed in quite an inefficient and overly complicated way so this detailed guide would be helpful to students and researchers unfamiliar with the website.
#
#
# > *Note 1. source codes and examples are from Prof. Jaehoon Lee (Kaist Business School)*\
# > *Note 2. The website is optimized for Korean speakers. If you do not speak Korean, I recommend you to still go for the Korean website and use in-browser translation services like Google translate.* \
# > *Note 3. The codes in this file was tested in July 2024. However, later updates in BOK system might be needed to be checked beforehand.*

# %%
#development enviornment
import requests
import pandas as pd

# %% [markdown]
# **Before we begin, you need to be issued an authentication key.**
#
# First, go to this website: [Bank of Korea Open API front page](https://ecos.bok.or.kr/api/#/)
#
# - If you do not speak Korean, use Google translate to translate the webpage.
#
# Second, sign up
#
# Third, apply for authetication key

# %%
BOK_API_URL = 'https://ecos.bok.or.kr/api'
BOK_API_KEY = 'IDI4QC444EYRWRBBQ8JN' #use your own authentication key here

# %% [markdown]
# ### Test the Open API

# %% [markdown]
# We will take a brief look at how BOK API is structured.
# Befor we begin,
#
# * Chrome browser is advised.
# * Get chrome extension, ["Jason Viewer"](https://chromewebstore.google.com/detail/json-viewer/gbmdgpbipfallnflgajpaliibnhdgobh?hl=en-US) from here, if you don't have it yet.

# %% [markdown]
# When you are done with above, take a look at the [development specification](https://ecos.bok.or.kr/api/#/DevGuide/DevSpeciflcation) for BOK API.
#
# Unfortunately, in order to download data of interest using BOK API, you need to get through several steps.
#
#
# 1. **[StatisticTableList]** Identify data of your interest from the list of available datasets.
#     - In this step, we obtain the code name for the dataset we require. (e.g., 731Y001)
#
#
# 2. **[StatisticItemList]** Identify items within the dataset.
#    - Here, we obtain the name of item we require
#
#
#
# 3. **[StatisticSearch]** Fectch item values
#    - We fetch data of our interest.

# %% [markdown]
# ## **1. Identify the code name for data set required**

# %% [markdown]
# Here, let's see the list of names of data they offer using 'StatisticsTableList'.

# %%
#100000 is a sufficiently larget arbitrary number to see all the list of data they offer.
url = f'{BOK_API_URL}/StatisticTableList/{BOK_API_KEY}/json/en/1/100000'

# %%
url
# Out:
# 'https://ecos.bok.or.kr/api/StatisticTableList/IDI4QC444EYRWRBBQ8JN/json/en/1/100000'

# %%
#[200] means success
requests.get(url)
# Out:
# <Response [200]>

# %%
resp = requests.get(url)

# %%
#List of data BOK offers
resp.json()
# Out:
# {'StatisticTableList': {'list_total_count': 977,
#   'row': [{'P_STAT_CODE': '*',
#     'STAT_CODE': '0000000001',
#     'STAT_NAME': '1. Monetary Financial Statistics',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000001',
#     'STAT_CODE': '0000000002',
#     'STAT_NAME': '1.1. Monetary and Liquidity Aggregates',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000002',
#     'STAT_CODE': '0000000003',
#     'STAT_NAME': '1.1.1. Monetary Base',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000003',
#     'STAT_CODE': '0000000004',
#     'STAT_NAME': '1.1.1.1. Components of Monetary Base',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000004',
#     'STAT_CODE': '102Y004',
#     'STAT_NAME': '1.1.1.1.1. Components of Monetary Base(Average, SA)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000004',
#     'STAT_CODE': '102Y002',
#     'STAT_NAME': '1.1.1.1.2. Components of Monetary Base(Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000004',
#     'STAT_CODE': '102Y003',
#     'STAT_NAME': '1.1.1.1.3. Components of Monetary Base(End of, SA)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000004',
#     'STAT_CODE': '102Y001',
#     'STAT_NAME': '1.1.1.1.4. Components of Monetary Base(End of) ',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000002',
#     'STAT_CODE': '0000000005',
#     'STAT_NAME': '1.1.2. M1(Narrow Money)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000005',
#     'STAT_CODE': '0000000006',
#     'STAT_NAME': '1.1.2.1. M1 By Type ',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000006',
#     'STAT_CODE': '101Y018',
#     'STAT_NAME': '1.1.2.1.1. M1 By Type (Average, SA)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000006',
#     'STAT_CODE': '101Y019',
#     'STAT_NAME': '1.1.2.1.2. M1 By Type (Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000006',
#     'STAT_CODE': '101Y016',
#     'STAT_NAME': '1.1.2.1.3. M1 By Type (End of, SA)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000006',
#     'STAT_CODE': '101Y017',
#     'STAT_NAME': '1.1.2.1.4. M1 By Type (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000002',
#     'STAT_CODE': '0000000007',
#     'STAT_NAME': '1.1.3. M2(Broad Money)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000007',
#     'STAT_CODE': '0000000008',
#     'STAT_NAME': '1.1.3.1. M2 By Type',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000008',
#     'STAT_CODE': '101Y003',
#     'STAT_NAME': '1.1.3.1.1. M2 By Type (Average, SA)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000008',
#     'STAT_CODE': '101Y004',
#     'STAT_NAME': '1.1.3.1.2. M2 By Type (Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000008',
#     'STAT_CODE': '101Y001',
#     'STAT_NAME': '1.1.3.1.3. M2 By Type (End of, SA)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000008',
#     'STAT_CODE': '101Y002',
#     'STAT_NAME': '1.1.3.1.4. M2 By Type (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000007',
#     'STAT_CODE': '0000000009',
#     'STAT_NAME': '1.1.3.2. M2 Sectoral Money Holdings',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000009',
#     'STAT_CODE': '101Y006',
#     'STAT_NAME': '1.1.3.2.1. Sectoral Money Holdings(Average, S.A.)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000009',
#     'STAT_CODE': '101Y015',
#     'STAT_NAME': '1.1.3.2.2. Sectoral Money Holdings(Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000009',
#     'STAT_CODE': '101Y005',
#     'STAT_NAME': '1.1.3.2.3. Sectoral Money Holdings(End of, S.A.)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000009',
#     'STAT_CODE': '101Y014',
#     'STAT_NAME': '1.1.3.2.4. Sectoral Money Holdings(End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000007',
#     'STAT_CODE': '0000000010',
#     'STAT_NAME': '1.1.3.3. M2 By Money Issuers',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000010',
#     'STAT_CODE': '101Y008',
#     'STAT_NAME': '1.1.3.3.1. M2 By Money Issuers (Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000010',
#     'STAT_CODE': '101Y007',
#     'STAT_NAME': '1.1.3.3.2. M2 By Money Issuers (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000002',
#     'STAT_CODE': '0000000012',
#     'STAT_NAME': '1.1.4. Lf By Type',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000012',
#     'STAT_CODE': '0000000013',
#     'STAT_NAME': '1.1.4.1. Lf By Type',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000013',
#     'STAT_CODE': '111Y003',
#     'STAT_NAME': '1.1.4.1.1. Lf By Type(Average, SA)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000013',
#     'STAT_CODE': '111Y004',
#     'STAT_NAME': '1.1.4.1.2. Lf By Type(Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000013',
#     'STAT_CODE': '111Y001',
#     'STAT_NAME': '1.1.4.1.3. Lf By Type(End of, SA)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000013',
#     'STAT_CODE': '111Y002',
#     'STAT_NAME': '1.1.4.1.4. Lf By Type(End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000012',
#     'STAT_CODE': '0000000014',
#     'STAT_NAME': '1.1.4.2. Lf by Liquidity Issuers',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000014',
#     'STAT_CODE': '111Y006',
#     'STAT_NAME': '1.1.4.2.1. Lf by Liquidity Issuers(Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000014',
#     'STAT_CODE': '111Y005',
#     'STAT_NAME': '1.1.4.2.2. Lf by Liquidity Issuers(End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000002',
#     'STAT_CODE': '0000000015',
#     'STAT_NAME': '1.1.5. L(Liquidity Aggregates)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000015',
#     'STAT_CODE': '112Y001',
#     'STAT_NAME': '1.1.5.1. L(Liquidity Aggregates)(End of, SA)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000015',
#     'STAT_CODE': '112Y002',
#     'STAT_NAME': '1.1.5.2. L(Liquidity Aggregates)(End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000002',
#     'STAT_CODE': '0000000017',
#     'STAT_NAME': '1.1.6. Depository Corporations Survey',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000017',
#     'STAT_CODE': '101Y009',
#     'STAT_NAME': '1.1.6.1. Depository Corporations Survey(End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000017',
#     'STAT_CODE': '101Y010',
#     'STAT_NAME': '1.1.6.2. Central Bank Survey (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000017',
#     'STAT_CODE': '101Y011',
#     'STAT_NAME': '1.1.6.3. Other Depository Corporations Survey (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000001',
#     'STAT_CODE': '0000000020',
#     'STAT_NAME': '1.2. Deposits, Loans & Discounts',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000020',
#     'STAT_CODE': '0000000021',
#     'STAT_NAME': '1.2.1. Deposits',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000021',
#     'STAT_CODE': '0000000022',
#     'STAT_NAME': '1.2.1.1. Deposits at CBs and SBs',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000022',
#     'STAT_CODE': '104Y014',
#     'STAT_NAME': '1.2.1.1.1. Total Deposits(Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000022',
#     'STAT_CODE': '104Y013',
#     'STAT_NAME': '1.2.1.1.2. Total Deposits(End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000022',
#     'STAT_CODE': '104Y008',
#     'STAT_NAME': '1.2.1.1.3. Deposits in Domestic Currency at CBs and SBs By Type (Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000022',
#     'STAT_CODE': '104Y015',
#     'STAT_NAME': '1.2.1.1.4. Deposits in Domestic Currency at CBs and SBs By Type (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000022',
#     'STAT_CODE': '104Y009',
#     'STAT_NAME': '1.2.1.1.5. Deposits in Domestic Currency at CBs and SBs By Depositors (End Of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000022',
#     'STAT_CODE': '104Y010',
#     'STAT_NAME': '1.2.1.1.6. Time Deposits in Domestic Currency at CBs and SBs By Term (End Of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000021',
#     'STAT_CODE': '0000000023',
#     'STAT_NAME': '1.2.1.2. Deposits at Non-Bank Financial Corporations',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000023',
#     'STAT_CODE': '111Y008',
#     'STAT_NAME': '1.2.1.2.1. Deposits at Non-Bank Financial Corporations (Average)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000023',
#     'STAT_CODE': '111Y007',
#     'STAT_NAME': '1.2.1.2.2. Deposits at Non-Bank Financial Corporations (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000020',
#     'STAT_CODE': '0000000024',
#     'STAT_NAME': '1.2.2. Loans & Discounts',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000024',
#     'STAT_CODE': '104Y016',
#     'STAT_NAME': '1.2.2.1. Loans & Discounts of CBs and SBs (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000024',
#     'STAT_CODE': '111Y009',
#     'STAT_NAME': '1.2.2.2. Loans & Discounts of Non-Bank Financial Corporations (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000020',
#     'STAT_CODE': '0000000027',
#     'STAT_NAME': '1.2.3. Total Deposits & Loians and Discounts by Region',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000027',
#     'STAT_CODE': '141Y002',
#     'STAT_NAME': '1.2.3.1. Total Deposits at CBs and SBs (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000027',
#     'STAT_CODE': '141Y006',
#     'STAT_NAME': '1.2.3.2. Total Deposits at Non-Bank Depository Corporations (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000027',
#     'STAT_CODE': '141Y008',
#     'STAT_NAME': '1.2.3.3. Total Deposits of Life Insurance Companies (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000027',
#     'STAT_CODE': '0000000031',
#     'STAT_NAME': '1.2.3.4. Loans & Discounts By Region (CBs & SBs, End of)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000031',
#     'STAT_CODE': '141Y003',
#     'STAT_NAME': '1.2.3.4.1. Loans & Discounts by Region (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000031',
#     'STAT_CODE': '151Y003',
#     'STAT_NAME': '1.2.3.4.2. Loans to Households by Region (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000031',
#     'STAT_CODE': '141Y004',
#     'STAT_NAME': '1.2.3.4.3. Loans to Enterprise by Region (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000027',
#     'STAT_CODE': '0000000032',
#     'STAT_NAME': '1.2.3.5. Loans & Discounts of Non-Bank Depository Corporations (End of)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000032',
#     'STAT_CODE': '141Y007',
#     'STAT_NAME': '1.2.3.5.1. Loans & Discounts of Non-Bank Depository Corporations by Region (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000032',
#     'STAT_CODE': '151Y006',
#     'STAT_NAME': '1.2.3.5.2. Loans to Households of Non-Bank Depository Corporations by Region (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000032',
#     'STAT_CODE': '141Y010',
#     'STAT_NAME': '1.2.3.5.3. Loans to Enterprise of Non-Bank Depository Corporations by Region (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000027',
#     'STAT_CODE': '141Y009',
#     'STAT_NAME': '1.2.3.6. Loans & Discounts of Life Insurance Companies (End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000027',
#     'STAT_CODE': '141Y005',
#     'STAT_NAME': '1.2.3.7. Delingquency Rate by Region (CBs & SBs, End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000020',
#     'STAT_CODE': '0000000035',
#     'STAT_NAME': '1.2.4. Credit to Households',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000035',
#     'STAT_CODE': '0000000036',
#     'STAT_NAME': '1.2.4.1. Credit to Households(Quarterly)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000036',
#     'STAT_CODE': '151Y001',
#     'STAT_NAME': '1.2.4.1.1. By Section',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000036',
#     'STAT_CODE': '151Y004',
#     'STAT_NAME': '1.2.4.1.2. By Purpose',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000035',
#     'STAT_CODE': '0000000037',
#     'STAT_NAME': '1.2.4.2. Loans to Households of Depository Corporations(Monthly)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000037',
#     'STAT_CODE': '151Y002',
#     'STAT_NAME': '1.2.4.2.1. By Section',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000037',
#     'STAT_CODE': '151Y005',
#     'STAT_NAME': '1.2.4.2.2. By Purpose',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000020',
#     'STAT_CODE': '0000000038',
#     'STAT_NAME': '1.2.5. Loans & Discounts by Industry',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000038',
#     'STAT_CODE': '0000000039',
#     'STAT_NAME': '1.2.5.1. Depository corporations',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000039',
#     'STAT_CODE': '131Y016',
#     'STAT_NAME': '1.2.5.1.1. All Industries',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000039',
#     'STAT_CODE': '131Y017',
#     'STAT_NAME': '1.2.5.1.2. By Purpose (Working Capital, Facilities Investment)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000038',
#     'STAT_CODE': '0000000040',
#     'STAT_NAME': '1.2.5.2. Commercial & Specialized Banks',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000040',
#     'STAT_CODE': '131Y013',
#     'STAT_NAME': '1.2.5.2.1. All Industries',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000040',
#     'STAT_CODE': '131Y011',
#     'STAT_NAME': '1.2.5.2.2. By Purpose (Working Capital, Facilities Investment)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000040',
#     'STAT_CODE': '131Y010',
#     'STAT_NAME': '1.2.5.2.3. By Type (Incorporation, Unincorporation)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000040',
#     'STAT_CODE': '131Y018',
#     'STAT_NAME': '1.2.5.2.4. By Size',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000040',
#     'STAT_CODE': '132Y001',
#     'STAT_NAME': '1.2.5.2.5. By Region',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000040',
#     'STAT_CODE': '132Y003',
#     'STAT_NAME': '1.2.5.2.6. By Region & Purpose',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000038',
#     'STAT_CODE': '0000000041',
#     'STAT_NAME': '1.2.5.3. Non-Bank Fainancial Corporations',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000041',
#     'STAT_CODE': '131Y014',
#     'STAT_NAME': '1.2.5.3.1. All Industries',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000041',
#     'STAT_CODE': '131Y015',
#     'STAT_NAME': '1.2.5.3.2. By Purpose (Working Capital, Facilities Investment)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000020',
#     'STAT_CODE': '0000000042',
#     'STAT_NAME': '1.2.6. Others Financial Statistics',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000042',
#     'STAT_CODE': '104Y017',
#     'STAT_NAME': '1.2.6.1. Turnover Ratios of Deposits of CBs & SBs',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000042',
#     'STAT_CODE': '901Y053',
#     'STAT_NAME': '1.2.6.2. Number of Branches and Employment by Financial Institution',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Financial Supervisory Service'},
#    {'P_STAT_CODE': '0000000042',
#     'STAT_CODE': '901Y054',
#     'STAT_NAME': '1.2.6.3. Delinquency Ratio for Bank Loans',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Financial Supervisory Service'},
#    {'P_STAT_CODE': '0000000042',
#     'STAT_CODE': '901Y059',
#     'STAT_NAME': '1.2.6.4. Business Results of Insurance Companies',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Korea Life Insurance Association(+82-2-2262-6600)'},
#    {'P_STAT_CODE': '0000000042',
#     'STAT_CODE': '105Y001',
#     'STAT_NAME': '1.2.6.5. The number of accounts and Outstanding amount by Size',
#     'CYCLE': 'S',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000001',
#     'STAT_CODE': '0000000048',
#     'STAT_NAME': '1.3. Interest Rates',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000048',
#     'STAT_CODE': '722Y001',
#     'STAT_NAME': '1.3.1. Bank of Korea Base Rate & Interest Rates on Loans and Discounts of the Bank of Korea',
#     'CYCLE': 'D',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000048',
#     'STAT_CODE': '0000000050',
#     'STAT_NAME': '1.3.2. Market Interest Rates',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000050',
#     'STAT_CODE': '817Y002',
#     'STAT_NAME': '1.3.2.1. Market Interest Rates(Daily)',
#     'CYCLE': 'D',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000050',
#     'STAT_CODE': '721Y001',
#     'STAT_NAME': '1.3.2.2. Market Interest Rates(Monthly, Quarterly, Annually)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000048',
#     'STAT_CODE': '0000000053',
#     'STAT_NAME': '1.3.3. CBs and SBs Weighted Averages of Interest Rates',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000053',
#     'STAT_CODE': '0000000054',
#     'STAT_NAME': '1.3.3.1. Interest Rates on Deposits',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000054',
#     'STAT_CODE': '121Y002',
#     'STAT_NAME': '1.3.3.1.1. Based on Newly Extended',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000054',
#     'STAT_CODE': '121Y013',
#     'STAT_NAME': '1.3.3.1.2. Based on Outstanding',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000053',
#     'STAT_CODE': '0000000055',
#     'STAT_NAME': '1.3.3.2. Interest Rates on Loans and Discounts',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000055',
#     'STAT_CODE': '121Y006',
#     'STAT_NAME': '1.3.3.2.1. Based on Newly Extended',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000055',
#     'STAT_CODE': '121Y015',
#     'STAT_NAME': '1.3.3.2.2. Based on Outstanding',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000053',
#     'STAT_CODE': '121Y008',
#     'STAT_NAME': '1.3.3.3. Shares of Deposits and Loans By Interest Rates Level (Newly Extended)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000053',
#     'STAT_CODE': '0000000057',
#     'STAT_NAME': '1.3.3.4. Shares of Loans at Fixed and Floating Interes Rates',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000057',
#     'STAT_CODE': '121Y010',
#     'STAT_NAME': '1.3.3.4.1. Based on Newly Extended',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000057',
#     'STAT_CODE': '121Y011',
#     'STAT_NAME': '1.3.3.4.2. Based on Outstanding',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000048',
#     'STAT_CODE': '0000000058',
#     'STAT_NAME': '1.3.4. NBFCs Weighted Averages of Interest Rates',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000058',
#     'STAT_CODE': '121Y004',
#     'STAT_NAME': '1.3.4.1. Interest Rates on Deposits',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000058',
#     'STAT_CODE': '121Y007',
#     'STAT_NAME': '1.3.4.2. Interest Rates on Loans and Discounts',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000001',
#     'STAT_CODE': '0000000061',
#     'STAT_NAME': '1.4. Main Accounts of the Bank of Korea',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000061',
#     'STAT_CODE': '103Y002',
#     'STAT_NAME': '1.4.1. Main Accounts of the Bank of Korea(End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000061',
#     'STAT_CODE': '871Y001',
#     'STAT_NAME': '1.4.2. Bank Notes and Coins Issued',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000061',
#     'STAT_CODE': '0000000064',
#     'STAT_NAME': '1.4.3. Reserves of Commercial and Specialized Banks',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000064',
#     'STAT_CODE': '814Y001',
#     'STAT_NAME': '1.4.3.1. Reserves of Commercial and Specialized Banks(New version, average of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000064',
#     'STAT_CODE': '814Y002',
#     'STAT_NAME': '1.4.3.2. Reserves of Commercial and Specialized Banks(Old version, average of)',
#     'CYCLE': 'SM',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000061',
#     'STAT_CODE': '641Y001',
#     'STAT_NAME': '1.4.4. Loans and Discounts in Won of the BOK(End of)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000001',
#     'STAT_CODE': '0000000397',
#     'STAT_NAME': '1.5. Securities, Bonds and Government Finance',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000397',
#     'STAT_CODE': '0000000398',
#     'STAT_NAME': '1.5.1. Transactions in Securiries and Stock Price index',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000398',
#     'STAT_CODE': '802Y001',
#     'STAT_NAME': '1.5.1.1. Stock Market(daily)',
#     'CYCLE': 'D',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Korea Exchange(+82-51-662-2000)'},
#    {'P_STAT_CODE': '0000000398',
#     'STAT_CODE': '901Y014',
#     'STAT_NAME': '1.5.1.2. Transactions in Securities and Stock Price Index',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Korea Exchange(+82-51-662-2000)'},
#    {'P_STAT_CODE': '0000000398',
#     'STAT_CODE': '901Y055',
#     'STAT_NAME': '1.5.1.3. Stock Trading by Investor Group',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Korea Exchange(+82-51-662-2000)'},
#    {'P_STAT_CODE': '0000000398',
#     'STAT_CODE': '901Y056',
#     'STAT_NAME': '1.5.1.4. Trends of Money in Securities Market',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'KOFlA(+82-2-2003-9000)'},
#    {'P_STAT_CODE': '0000000398',
#     'STAT_CODE': '901Y057',
#     'STAT_NAME': '1.5.1.5. Transactions for Stock Price Index Futures',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Korea Exchange(+82-51-662-2000)'},
#    {'P_STAT_CODE': '0000000398',
#     'STAT_CODE': '901Y058',
#     'STAT_NAME': '1.5.1.6. Transactions for Stock Price Index',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Korea Exchange(+82-51-662-2000)'},
#    {'P_STAT_CODE': '0000000397',
#     'STAT_CODE': '901Y015',
#     'STAT_NAME': '1.5.2. Trade of Bonds',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Korea Exchange(+82-51-662-2000)'},
#    {'P_STAT_CODE': '0000000397',
#     'STAT_CODE': '191Y001',
#     'STAT_NAME': '1.5.3. Issues and Outstanding Amounts of Principal Government, Public and Corporate Bonds',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000397',
#     'STAT_CODE': '0000000399',
#     'STAT_NAME': '1.5.4. Central Governmnet Fiscal Balance',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000399',
#     'STAT_CODE': '901Y013',
#     'STAT_NAME': '1.5.4.1. Central Governmnet Fiscal Balance',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Ministry of Economy and Finance(+82-44-215-2114)'},
#    {'P_STAT_CODE': '0000000399',
#     'STAT_CODE': '901Y081',
#     'STAT_NAME': '1.5.4.2. Amount of Tax Collection',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Ministry of Strategy and Finance(+82-44-215-2114)'},
#    {'P_STAT_CODE': '*',
#     'STAT_CODE': '0000000066',
#     'STAT_NAME': '2. National Accounts',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000066',
#     'STAT_CODE': '0000000910',
#     'STAT_NAME': '2.1. National Income and Product (reference year 2020)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000911',
#     'STAT_NAME': '2.1.1. Main Indicators of National Accounts',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000911',
#     'STAT_CODE': '200Y101',
#     'STAT_NAME': '2.1.1.1. Main Annual Indicators (reference year 2020)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000911',
#     'STAT_CODE': '200Y102',
#     'STAT_NAME': '2.1.1.2. Main Quarterly Indicators  (reference year 2020)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000912',
#     'STAT_NAME': '2.1.2. GDP and GDP Deflator by Economic Activities and Expenditures',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000912',
#     'STAT_CODE': '0000000913',
#     'STAT_NAME': '2.1.2.1. GDP and GNI by Economic Activities',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000913',
#     'STAT_CODE': '200Y103',
#     'STAT_NAME': '2.1.2.1.1. GDP and GNI by Economic Activities (seasonally adjusted, current prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000913',
#     'STAT_CODE': '200Y104',
#     'STAT_NAME': '2.1.2.1.2. GDP and GNI by Economic Activities (seasonally adjusted, chained 2020 year prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000913',
#     'STAT_CODE': '200Y105',
#     'STAT_NAME': '2.1.2.1.3. GDP and GNI by Economic Activities (not seasonally adjusted, current prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000913',
#     'STAT_CODE': '200Y106',
#     'STAT_NAME': '2.1.2.1.4. GDP and GNI by Economic Activities (not seasonally adjusted, chained 2020 year prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000912',
#     'STAT_CODE': '0000000914',
#     'STAT_NAME': '2.1.2.2. Expenditures on Gross Domestic Product',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000914',
#     'STAT_CODE': '200Y107',
#     'STAT_NAME': '2.1.2.2.1. Expenditures on GDP (seasonally adjusted, current prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000914',
#     'STAT_CODE': '200Y108',
#     'STAT_NAME': '2.1.2.2.2. Expenditures on GDP (seasonally adjusted, chained 2020 year prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000914',
#     'STAT_CODE': '200Y109',
#     'STAT_NAME': '2.1.2.2.3. Expenditures on GDP (not seasonally adjusted, current prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000914',
#     'STAT_CODE': '200Y110',
#     'STAT_NAME': '2.1.2.2.4. Expenditures on GDP (not seasonally adjusted, chained 2020 year prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000912',
#     'STAT_CODE': '0000000915',
#     'STAT_NAME': '2.1.2.3. GDP Deflator',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000915',
#     'STAT_CODE': '200Y111',
#     'STAT_NAME': '2.1.2.3.1. GDP Deflator by Economic Activities (not seasonally adjusted, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000915',
#     'STAT_CODE': '200Y112',
#     'STAT_NAME': '2.1.2.3.2. GDP Deflator by Expenditures on GDP (not seasonally adjusted, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000916',
#     'STAT_NAME': '2.1.3. Consolidated Accounts for the Nation',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000916',
#     'STAT_CODE': '0000000917',
#     'STAT_NAME': '2.1.3.1. Gross Domestic Product and Expenditure',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000917',
#     'STAT_CODE': '200Y113',
#     'STAT_NAME': '2.1.3.1.1. Gross Domestic Product and Expenditure (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000917',
#     'STAT_CODE': '200Y114',
#     'STAT_NAME': '2.1.3.1.2. Gross Value Added and Factor Income by Economic Activities (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000916',
#     'STAT_CODE': '0000000918',
#     'STAT_NAME': '2.1.3.2. National Disposable Income and Its Appropriation',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000918',
#     'STAT_CODE': '200Y115',
#     'STAT_NAME': '2.1.3.2.1. National Disposable Income and Its Appropriation (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000918',
#     'STAT_CODE': '200Y116',
#     'STAT_NAME': '2.1.3.2.2. National Income and National Disposable Income (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000916',
#     'STAT_CODE': '0000000919',
#     'STAT_NAME': '2.1.3.3. Capital Transactions',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000919',
#     'STAT_CODE': '200Y117',
#     'STAT_NAME': '2.1.3.3.1. Capital Transactions (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000916',
#     'STAT_CODE': '0000000920',
#     'STAT_NAME': '2.1.3.4. External Transactions',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000920',
#     'STAT_CODE': '200Y118',
#     'STAT_NAME': '2.1.3.4.1. Current Transactions (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000920',
#     'STAT_CODE': '200Y119',
#     'STAT_NAME': '2.1.3.4.2. Capital Transactions (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000921',
#     'STAT_NAME': '2.1.4. Production, Income and Capital Accounts by Institutional Sectors',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000921',
#     'STAT_CODE': '200Y120',
#     'STAT_NAME': '2.1.4.1. Production Accounts by Institutional Sectors (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000921',
#     'STAT_CODE': '200Y121',
#     'STAT_NAME': '2.1.4.2. Income Accounts by Institutional Sectors (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000921',
#     'STAT_CODE': '200Y122',
#     'STAT_NAME': '2.1.4.3. Capital Accounts by Institutional Sectors (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000922',
#     'STAT_NAME': '2.1.5. Contributions to Real GDP Growth',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000922',
#     'STAT_CODE': '200Y123',
#     'STAT_NAME': '2.1.5.1. Contributions to Real GDP Growth by Economic Activities (seasonally adjusted, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000922',
#     'STAT_CODE': '200Y124',
#     'STAT_NAME': '2.1.5.2. Contributions to Real GDP Growth by Economic Activities (not seasonally adjusted, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000922',
#     'STAT_CODE': '200Y125',
#     'STAT_NAME': '2.1.5.3. Contributions to Real GDP Growth by Expenditures (seasonally adjusted, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000922',
#     'STAT_CODE': '200Y126',
#     'STAT_NAME': '2.1.5.4. Contributions to Real GDP Growth by Expenditures (not seasonally adjusted, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000923',
#     'STAT_NAME': '2.1.6. Gross Capital Formation',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000923',
#     'STAT_CODE': '0000000924',
#     'STAT_NAME': '2.1.6.1. Gross Capital Formation by Type of Capital Goods',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000924',
#     'STAT_CODE': '200Y127',
#     'STAT_NAME': '2.1.6.1.1. Gross Capital Formation by Type of Capital Goods (seasonally adjusted, current prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000924',
#     'STAT_CODE': '200Y128',
#     'STAT_NAME': '2.1.6.1.2. Gross Capital Formation by Type of Capital Goods (seasonally adjusted, chained 2020 year prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000924',
#     'STAT_CODE': '200Y129',
#     'STAT_NAME': '2.1.6.1.3. Gross Capital Formation by Type of Capital Goods (not seasonally adjusted, current prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000924',
#     'STAT_CODE': '200Y130',
#     'STAT_NAME': '2.1.6.1.4. Gross Capital Formation by Type of Capital Goods (not seasonally adjusted, chained 2020 year prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000923',
#     'STAT_CODE': '0000000925',
#     'STAT_NAME': '2.1.6.2. Gross Capital Formation by Sectors',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000925',
#     'STAT_CODE': '200Y131',
#     'STAT_NAME': '2.1.6.2.1. Gross Capital Formation by Sectors (not seasonally adjusted, current prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000925',
#     'STAT_CODE': '200Y132',
#     'STAT_NAME': '2.1.6.2.2. Gross Capital Formation by Sectors (not seasonally adjusted, chained 2020 year prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000925',
#     'STAT_CODE': '200Y133',
#     'STAT_NAME': '2.1.6.2.3. Gross Fixed Capital Formation by Sectors (seasonally adjusted, current prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000925',
#     'STAT_CODE': '200Y134',
#     'STAT_NAME': '2.1.6.2.4. Gross Fixed Capital Formation by Sectors (seasonally adjusted, chained 2020 year prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000928',
#     'STAT_NAME': '2.1.7. Final Consumption Expenditure',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000928',
#     'STAT_CODE': '0000000929',
#     'STAT_NAME': '2.1.7.1. Final Consumption Expenditure of Resident Households by Purpose',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000929',
#     'STAT_CODE': '200Y140',
#     'STAT_NAME': '2.1.7.1.1. Final Consumption Expenditure of Resident Households by Purpose (seasonally adjusted, current prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000929',
#     'STAT_CODE': '200Y141',
#     'STAT_NAME': '2.1.7.1.2. Final Consumption Expenditure of Resident Households by Purpose (seasonally adjusted, chained 2020 year prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000929',
#     'STAT_CODE': '200Y142',
#     'STAT_NAME': '2.1.7.1.3. Final Consumption Expenditure of Resident Households by Purpose (not seasonally adjusted, current prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000929',
#     'STAT_CODE': '200Y143',
#     'STAT_NAME': '2.1.7.1.4. Final Consumption Expenditure of Resident Households by Purpose (not seasonally adjusted, chained 2020 year prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000928',
#     'STAT_CODE': '0000000930',
#     'STAT_NAME': '2.1.7.2. Final Consumption Expenditure of Resident Households by Type',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000930',
#     'STAT_CODE': '200Y144',
#     'STAT_NAME': '2.1.7.2.1. Final Consumption Expenditure of Resident Households by Type (seasonally adjusted, current prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000930',
#     'STAT_CODE': '200Y145',
#     'STAT_NAME': '2.1.7.2.2. Final Consumption Expenditure of Resident Households by Type (seasonally adjusted, chained 2020 year prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000930',
#     'STAT_CODE': '200Y146',
#     'STAT_NAME': '2.1.7.2.3. Final Consumption Expenditure of Resident Households by Type (not seasonally adjusted, current prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000930',
#     'STAT_CODE': '200Y147',
#     'STAT_NAME': '2.1.7.2.4. Final Consumption Expenditure of Resident Households by Type (not seasonally adjusted, chained 2020 year prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000928',
#     'STAT_CODE': '0000000931',
#     'STAT_NAME': '2.1.7.3. Final Consumption Expenditure of NPISH by Purpose',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000931',
#     'STAT_CODE': '200Y148',
#     'STAT_NAME': '2.1.7.3.1. Final Consumption Expenditure of NPISH by Purpose (not seasonally adjusted, current prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000931',
#     'STAT_CODE': '200Y149',
#     'STAT_NAME': '2.1.7.3.2. Final Consumption Expenditure of NPISH by Purpose (not seasonally adjusted, chained 2020 year prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000932',
#     'STAT_NAME': '2.1.8. General Government and Public Sector Accounts',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000932',
#     'STAT_CODE': '200Y151',
#     'STAT_NAME': '2.1.8.1. General Government Final Consumption Expenditure by Function (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000932',
#     'STAT_CODE': '200Y152',
#     'STAT_NAME': '2.1.8.2. General Government Total Expenditure by Function (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000932',
#     'STAT_CODE': '200Y153',
#     'STAT_NAME': '2.1.8.3. General Government Total Revenue and Total Expenditure (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000932',
#     'STAT_CODE': '200Y154',
#     'STAT_NAME': '2.1.8.4. Public Sector Total Revenue and Total Expenditure (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000933',
#     'STAT_NAME': '2.1.9. Gross Savings and Gross Investments ',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000933',
#     'STAT_CODE': '200Y155',
#     'STAT_NAME': '2.1.9.1. Gross Savings and Gross Investments (seasonally adjusted, current prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000933',
#     'STAT_CODE': '200Y156',
#     'STAT_NAME': '2.1.9.2. Gross Savings and Gross Investments (not seasonally adjusted, current prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000934',
#     'STAT_NAME': '2.1.10. Information and Communication Technologies (chained 2020 year prices)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000934',
#     'STAT_CODE': '200Y157',
#     'STAT_NAME': '2.1.10.1. Information and Communication Technologies (seasonally adjusted, chained 2020 year prices, quarterly)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000934',
#     'STAT_CODE': '200Y158',
#     'STAT_NAME': '2.1.10.2. Information and Communication Technologies (not seasonally adjusted, chained 2020 year prices, quarterly & annual)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000910',
#     'STAT_CODE': '0000000935',
#     'STAT_NAME': '2.1.11. Household Distributional Accounts (experimental statistics)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000935',
#     'STAT_CODE': '200Y159',
#     'STAT_NAME': '2.1.11.1. Household Distributional Accounts (current prices, annual)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000066',
#     'STAT_CODE': '0000000110',
#     'STAT_NAME': '2.2. Input-Output Tables',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000110',
#     'STAT_CODE': '0000000901',
#     'STAT_NAME': '2.2.1. 2020 Benchmark Year',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000901',
#     'STAT_CODE': '0000000902',
#     'STAT_NAME': '2.2.1.1. Download Files',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000902',
#     'STAT_CODE': '271Y105',
#     'STAT_NAME': '2020 Benchmark Tables',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000902',
#     'STAT_CODE': '271Y108',
#     'STAT_NAME': '2020 Sector classifications',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000902',
#     'STAT_CODE': '271Y109',
#     'STAT_NAME': 'Employment Tables',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000901',
#     'STAT_CODE': '0000000903',
#     'STAT_NAME': '2.2.1.2. Data',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000903',
#     'STAT_CODE': '271Y110',
#     'STAT_NAME': "2.2.1.2.1. Input-Output : Total transactions(Producer's price, Large-sized)",
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000903',
#     'STAT_CODE': '271Y111',
#     'STAT_NAME': "2.2.1.2.2. Input-Output : Input coefficients(Producer's price, Large-sized)",
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000903',
#     'STAT_CODE': '271Y112',
#     'STAT_NAME': "2.2.1.2.3. Input-Output : Production requirement coefficients(Producer's price, Large-sized)",
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000903',
#     'STAT_CODE': '271Y113',
#     'STAT_NAME': "2.2.1.2.4. Input-Output : Import requirement coefficients(Producer's price, Large-sized)",
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000903',
#     'STAT_CODE': '271Y114',
#     'STAT_NAME': "2.2.1.2.5. Input-Output : Value added requirement coefficients(Producer's price, Large-sized)",
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000903',
#     'STAT_CODE': '271Y115',
#     'STAT_NAME': "2.2.1.2.6. Input-Output : Total workers requirement coefficients(Producer's price, Large-sized)",
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000903',
#     'STAT_CODE': '271Y116',
#     'STAT_NAME': "2.2.1.2.7. Input-Output : Employees requirement coefficients(Producer's price, Large-sized)",
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000903',
# ...
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000701',
#     'STAT_CODE': '903Y202',
#     'STAT_NAME': '8.7.1.2. Household assets liabilities and income by the kind of house(2021~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000701',
#     'STAT_CODE': '903Y203',
#     'STAT_NAME': '8.7.1.3. Household assets liabilities and income by the type of housing(2021~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000701',
#     'STAT_CODE': '903Y204',
#     'STAT_NAME': '8.7.1.4. Household assets liabilities and income by the number of household members(2021~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000701',
#     'STAT_CODE': '903Y205',
#     'STAT_NAME': '8.7.1.5. Household assets liabilities and income by age groups of households head (10age)(2022~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000701',
#     'STAT_CODE': '903Y206',
#     'STAT_NAME': '8.7.1.5. Household assets liabilities and income by age groups of households head (10age)(2021~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000701',
#     'STAT_CODE': '903Y209',
#     'STAT_NAME': '8.7.1.6. Household assets liabilities and income by the status of worker of Household head(2021~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000701',
#     'STAT_CODE': '903Y210',
#     'STAT_NAME': '8.7.1.7. Household assets liabilities and income by income quintiles(2021~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000701',
#     'STAT_CODE': '903Y211',
#     'STAT_NAME': '8.7.1.8. Household assets liabilities and income by assets quintiles(2021~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000701',
#     'STAT_CODE': '903Y212',
#     'STAT_NAME': '8.7.1.9. Household assets liabilities and income by net worth quintiles(2021~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000700',
#     'STAT_CODE': '0000000702',
#     'STAT_NAME': '8.7.2. Survey of Household Finances and Living Conditions(2017~2022)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000702',
#     'STAT_CODE': '903Y101',
#     'STAT_NAME': '8.7.2.1. Household assets, liabilities and income by provinces(2017~2022)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000702',
#     'STAT_CODE': '903Y102',
#     'STAT_NAME': '8.7.2.2. Household assets, liabilities and income by the kind of house(2017~2022)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000702',
#     'STAT_CODE': '903Y103',
#     'STAT_NAME': '8.7.2.3. Household assets, liabilities and income by the type of housing(2017~2022)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000702',
#     'STAT_CODE': '903Y104',
#     'STAT_NAME': '8.7.2.4. Household assets, liabilities and income by the number of household members(2017~2022)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000702',
#     'STAT_CODE': '903Y106',
#     'STAT_NAME': '8.7.2.5. Household assets, liabilities and income by age groups of households head (10age)(2017~2022)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000702',
#     'STAT_CODE': '903Y109',
#     'STAT_NAME': '8.7.2.6. Household assets, liabilities and income by the status of worker of Household head(2017~2022)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000702',
#     'STAT_CODE': '903Y110',
#     'STAT_NAME': '8.7.2.7. Household assets, liabilities and income by income quintiles(2017~2022)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000702',
#     'STAT_CODE': '903Y111',
#     'STAT_NAME': '8.7.2.8. Household assets, liabilities and income by assets quintiles(2017~2022)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000702',
#     'STAT_CODE': '903Y112',
#     'STAT_NAME': '8.7.2.9. Household assets, liabilities and income by net worth quintiles(2017~2022)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000700',
#     'STAT_CODE': '0000000703',
#     'STAT_NAME': '8.7.3. Survey of Household Finances and Living Conditions(2012~2017)',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000703',
#     'STAT_CODE': '903Y001',
#     'STAT_NAME': '8.7.3.1. Household assets, liabilities and income by provinces (2012 ~ 2017)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000703',
#     'STAT_CODE': '903Y002',
#     'STAT_NAME': '8.7.3.2. Household assets, liabilities and income by the kind of house (2012 ~ 2017)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000703',
#     'STAT_CODE': '903Y003',
#     'STAT_NAME': '8.7.3.3. Household assets, liabilities and income by the type of housing (2012 ~ 2017)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000703',
#     'STAT_CODE': '903Y004',
#     'STAT_NAME': '8.7.3.4. Household assets, liabilities and income by the number of household members (2012 ~ 2017)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000703',
#     'STAT_CODE': '903Y006',
#     'STAT_NAME': '8.7.3.5. Household assets, liabilities and income by age groups of households head (10age) (2012 ~ 2017)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000703',
#     'STAT_CODE': '903Y009',
#     'STAT_NAME': '8.7.3.6. Household assets, liabilities and income by the status of worker of Household head (2012 ~ 2017)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000703',
#     'STAT_CODE': '903Y010',
#     'STAT_NAME': '8.7.3.7. Household assets, liabilities and income by income quintiles (2012 ~ 2017)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000703',
#     'STAT_CODE': '903Y011',
#     'STAT_NAME': '8.7.3.8. Household assets, liabilities and income by assets quintiles (2012 ~ 2017)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000703',
#     'STAT_CODE': '903Y012',
#     'STAT_NAME': '8.7.3.9. Household assets, liabilities and income by net worth quintiles (2012 ~ 2017)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-44-201-3328)'},
#    {'P_STAT_CODE': '0000000700',
#     'STAT_CODE': '901Y112',
#     'STAT_NAME': '8.7.4. The Index of Income Distribution(2020~)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-42-481-2305 )'},
#    {'P_STAT_CODE': '0000000700',
#     'STAT_CODE': '901Y031',
#     'STAT_NAME': '8.7.5. The Index of Income Distribution(2011~2021)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-42-481-2278)'},
#    {'P_STAT_CODE': '0000000700',
#     'STAT_CODE': '901Y040',
#     'STAT_NAME': '8.7.6. Average Monthly Income & Expenditure (Whole Households)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-42-481-2289)'},
#    {'P_STAT_CODE': '0000000700',
#     'STAT_CODE': '901Y050',
#     'STAT_NAME': '8.7.7. Average Monthly Income & Expenditure (Whole excl.1 Person and Farm)',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-42-481-2289)'},
#    {'P_STAT_CODE': '0000000700',
#     'STAT_CODE': '901Y024',
#     'STAT_NAME': '8.7.8. Income and Expenditure of Farm Households',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Statistics Korea(☎ +82-42-481-2306 )'},
#    {'P_STAT_CODE': '*',
#     'STAT_CODE': '0000000394',
#     'STAT_NAME': '9. Foreign Countries/North Korea',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000394',
#     'STAT_CODE': '0000000395',
#     'STAT_NAME': '9.1. International Key Statistics',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000395',
#     'STAT_CODE': '0000000441',
#     'STAT_NAME': '9.1.1. Monetary Aggregates & Policy Rate',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000441',
#     'STAT_CODE': '902Y004',
#     'STAT_NAME': '9.1.1.1. Internatioanl Monetary base',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000441',
#     'STAT_CODE': '902Y005',
#     'STAT_NAME': '9.1.1.2. International Broad Money',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000441',
#     'STAT_CODE': '902Y006',
#     'STAT_NAME': '9.1.1.3. International Central Bank Policy Rate',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'BIS'},
#    {'P_STAT_CODE': '0000000395',
#     'STAT_CODE': '0000000442',
#     'STAT_NAME': '9.1.2. Prices',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000442',
#     'STAT_CODE': '902Y007',
#     'STAT_NAME': '9.1.2.1. Internatioanl Producer Price indices',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000442',
#     'STAT_CODE': '902Y008',
#     'STAT_NAME': '9.1.2.2. International Consumer Price indices',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000395',
#     'STAT_CODE': '0000000443',
#     'STAT_NAME': '9.1.3. Balance of Payments/Trade/Foreign Reserve',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000443',
#     'STAT_CODE': '902Y009',
#     'STAT_NAME': '9.1.3.1. Internatioanl Current Account, Total, Net, US Dollars',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000443',
#     'STAT_CODE': '902Y010',
#     'STAT_NAME': '9.1.3.2. Internatioanl Current Account, Goods and Services, Goods, Net, US Dollars',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000443',
#     'STAT_CODE': '902Y011',
#     'STAT_NAME': '9.1.3.3. Internatioanl Current Account, Goods and Services, Services, Net, US Dollars',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000443',
#     'STAT_CODE': '902Y012',
#     'STAT_NAME': '9.1.3.4. Internatioanl Goods, Value of Exports, Free on board (FOB), US Dollars',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000443',
#     'STAT_CODE': '902Y013',
#     'STAT_NAME': '9.1.3.5. International Goods, Value of Imports, Cost, Insurance, Freight (CIF), US Dollars',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000443',
#     'STAT_CODE': '902Y014',
#     'STAT_NAME': '9.1.3.6. International Official Reserve Assets, US Dollars',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'IMF'},
#    {'P_STAT_CODE': '0000000395',
#     'STAT_CODE': '0000000444',
#     'STAT_NAME': '9.1.4. GDP/GNI',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000444',
#     'STAT_CODE': '902Y015',
#     'STAT_NAME': '9.1.4.1. International Growth Rate of GDP',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000444',
#     'STAT_CODE': '902Y016',
#     'STAT_NAME': '9.1.4.2. GDP',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000444',
#     'STAT_CODE': '902Y019',
#     'STAT_NAME': '9.1.4.3. Gross domestic product(PPPs)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000444',
#     'STAT_CODE': '902Y017',
#     'STAT_NAME': '9.1.4.4. GNI',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000444',
#     'STAT_CODE': '902Y018',
#     'STAT_NAME': '9.1.4.5. Per Capita GDP',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000395',
#     'STAT_CODE': '0000000445',
#     'STAT_NAME': '9.1.5. Industry & Employment',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000445',
#     'STAT_CODE': '902Y020',
#     'STAT_NAME': '9.1.5.1. Industrial Production indices(S.A.)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000445',
#     'STAT_CODE': '902Y021',
#     'STAT_NAME': '9.1.5.2. Unemployment Rates(S.A.)',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000445',
#     'STAT_CODE': '902Y022',
#     'STAT_NAME': '9.1.5.3. Number of Employment(S.A.)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000395',
#     'STAT_CODE': '0000000446',
#     'STAT_NAME': '9.1.6. Financial Market Key Indicators',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000446',
#     'STAT_CODE': '902Y023',
#     'STAT_NAME': '9.1.6.1. Financial Market Key Indicators',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000446',
#     'STAT_CODE': '902Y002',
#     'STAT_NAME': '9.1.6.2. Stock price indices',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'OECD'},
#    {'P_STAT_CODE': '0000000446',
#     'STAT_CODE': '902Y003',
#     'STAT_NAME': '9.1.6.3. World Commodity Prices',
#     'CYCLE': 'M',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000394',
#     'STAT_CODE': '0000000396',
#     'STAT_NAME': '9.2. Economic Indicators of North Korea ',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000396',
#     'STAT_CODE': '0000000447',
#     'STAT_NAME': '9.2.1. Major Indicators Comparison between South Korea and North Korea',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000447',
#     'STAT_CODE': '251Y003',
#     'STAT_NAME': '9.2.1.1. Major Indicators Comparison between South Korea and North Korea',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000447',
#     'STAT_CODE': '251Y002',
#     'STAT_NAME': '9.2.1.2. Major Indicators Comparison(Ratio of South to North Korea)',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000396',
#     'STAT_CODE': '251Y001',
#     'STAT_NAME': '9.2.2. North Korea GDP',
#     'CYCLE': 'A',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000396',
#     'STAT_CODE': '0000000704',
#     'STAT_NAME': '9.2.3. Market Prices and Exchange Rate in North Korea',
#     'CYCLE': None,
#     'SRCH_YN': 'N',
#     'ORG_NAME': None},
#    {'P_STAT_CODE': '0000000704',
#     'STAT_CODE': '252Y001',
#     'STAT_NAME': '9.2.3.1. Market price indices',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'},
#    {'P_STAT_CODE': '0000000704',
#     'STAT_CODE': '252Y002',
#     'STAT_NAME': '9.2.3.2. Market exchange rate',
#     'CYCLE': 'Q',
#     'SRCH_YN': 'Y',
#     'ORG_NAME': 'Bank of Korea'}]}}

# %%
results = resp.json()

# %%
rows = results['StatisticTableList']['row']

# %%
df = pd.DataFrame(rows)

# %%
df
# Out:
#     P_STAT_CODE   STAT_CODE  \
# 0             *  0000000001
# 1    0000000001  0000000002
# 2    0000000002  0000000003
# 3    0000000003  0000000004
# 4    0000000004     102Y004
# ..          ...         ...
# 972  0000000447     251Y002
# 973  0000000396     251Y001
# 974  0000000396  0000000704
# 975  0000000704     252Y001
# 976  0000000704     252Y002
#
#                                              STAT_NAME CYCLE SRCH_YN  \
# 0                     1. Monetary Financial Statistics  None       N
# 1               1.1. Monetary and Liquidity Aggregates  None       N
# 2                                 1.1.1. Monetary Base  None       N
# 3                 1.1.1.1. Components of Monetary Base  None       N
# 4    1.1.1.1.1. Components of Monetary Base(Average...     M       Y
# ..                                                 ...   ...     ...
# 972  9.2.1.2. Major Indicators Comparison(Ratio of ...     A       Y
# 973                             9.2.2. North Korea GDP     A       Y
# 974  9.2.3. Market Prices and Exchange Rate in Nort...  None       N
# 975                      9.2.3.1. Market price indices     Q       Y
# 976                      9.2.3.2. Market exchange rate     Q       Y
#
#           ORG_NAME
# 0             None
# 1             None
# 2             None
# 3             None
# 4    Bank of Korea
# ..             ...
# 972  Bank of Korea
# 973  Bank of Korea
# 974           None
# 975  Bank of Korea
# 976  Bank of Korea
#
# [977 rows x 6 columns]

# %% [markdown]
# ### Make a function to fetch data

# %% [markdown]
# Above codes are made into a function.

# %%
def fetch_bok_data(service_code, stat_code = None):
    url = f'{BOK_API_URL}/{service_code}/{BOK_API_KEY}/json/en/1/100000' #10000 is sufficiently large, but arbitrary number

    if stat_code:
        url += f'/{stat_code}' 
    
    print(url)
    resp = requests.get(url)
    results = resp.json()
    rows = results[service_code]['row']
    df = pd.DataFrame(rows)

    return df

# %%
fetch_bok_data('StatisticTableList')
# Out:
# https://ecos.bok.or.kr/api/StatisticTableList/IDI4QC444EYRWRBBQ8JN/json/en/1/100000
#     P_STAT_CODE   STAT_CODE  \
# 0             *  0000000001
# 1    0000000001  0000000002
# 2    0000000002  0000000003
# 3    0000000003  0000000004
# 4    0000000004     102Y004
# ..          ...         ...
# 972  0000000447     251Y002
# 973  0000000396     251Y001
# 974  0000000396  0000000704
# 975  0000000704     252Y001
# 976  0000000704     252Y002
#
#                                              STAT_NAME CYCLE SRCH_YN  \
# 0                     1. Monetary Financial Statistics  None       N
# 1               1.1. Monetary and Liquidity Aggregates  None       N
# 2                                 1.1.1. Monetary Base  None       N
# 3                 1.1.1.1. Components of Monetary Base  None       N
# 4    1.1.1.1.1. Components of Monetary Base(Average...     M       Y
# ..                                                 ...   ...     ...
# 972  9.2.1.2. Major Indicators Comparison(Ratio of ...     A       Y
# 973                             9.2.2. North Korea GDP     A       Y
# 974  9.2.3. Market Prices and Exchange Rate in Nort...  None       N
# 975                      9.2.3.1. Market price indices     Q       Y
# 976                      9.2.3.2. Market exchange rate     Q       Y
#
#           ORG_NAME
# 0             None
# 1             None
# 2             None
# 3             None
# 4    Bank of Korea
# ..             ...
# 972  Bank of Korea
# 973  Bank of Korea
# 974           None
# 975  Bank of Korea
# 976  Bank of Korea
#
# [977 rows x 6 columns]

# %% [markdown]
# ### Filter with condition

# %%
df['STAT_NAME']
# Out:
# 0                       1. Monetary Financial Statistics
# 1                 1.1. Monetary and Liquidity Aggregates
# 2                                   1.1.1. Monetary Base
# 3                   1.1.1.1. Components of Monetary Base
# 4      1.1.1.1.1. Components of Monetary Base(Average...
#                              ...
# 972    9.2.1.2. Major Indicators Comparison(Ratio of ...
# 973                               9.2.2. North Korea GDP
# 974    9.2.3. Market Prices and Exchange Rate in Nort...
# 975                        9.2.3.1. Market price indices
# 976                        9.2.3.2. Market exchange rate
# Name: STAT_NAME, Length: 977, dtype: object

# %%
#indices are made to identify the name of data of our interest that is exchange rate data
idx1 = df['STAT_NAME'].str.lower().str.find('against') >= 0
idx2 = df['STAT_NAME'].str.lower().str.find('won') >= 0

# %%
#731Y001 is what we need
df[idx1 & idx2]
# Out:
#     P_STAT_CODE STAT_CODE                                          STAT_NAME  \
# 568  0000000178   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...
# 570  0000000178   731Y003  3.1.1.3. Exchange Rate of Won Against US Dolla...
# 572  0000000182   731Y004  3.1.2.1. Arbitraged Rates of Major Currencies ...
# 574  0000000182   731Y006  3.1.2.3. Exchange Rate of Won Against US Dolla...
#
#     CYCLE SRCH_YN                    ORG_NAME
# 568     D       Y  Seoul Money Broker Service
# 570     D       Y               Bank of Korea
# 572     M       Y               Bank of Korea
# 574     M       Y               Bank of Korea

# %% [markdown]
# > We successfully identified the code name for dataset we require, 731Y001.

# %% [markdown]
# ## **2. Identify the item of interest**

# %% [markdown]
# Now that we identify the data set we require, with that we can see through the items consisting of the very dataset.

# %%
fetch_bok_data('StatisticItemList', stat_code = '731Y001')
# Out:
# https://ecos.bok.or.kr/api/StatisticItemList/IDI4QC444EYRWRBBQ8JN/json/en/1/100000/731Y001
#    STAT_CODE                                          STAT_NAME GRP_CODE  \
# 0    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 1    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 2    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 3    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 4    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 5    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 6    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 7    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 8    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 9    731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 10   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 11   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 12   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 13   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 14   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 15   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 16   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 17   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 18   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 19   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 20   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 21   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 22   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 23   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 24   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 25   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 26   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 27   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 28   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 29   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 30   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 31   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 32   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 33   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 34   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 35   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 36   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 37   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 38   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 39   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 40   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 41   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 42   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 43   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 44   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 45   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 46   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 47   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 48   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 49   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 50   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 51   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
# 52   731Y001  3.1.1.1. Arbitraged Rates of Major Currencies ...   Group1
#
#                    GRP_NAME ITEM_CODE  \
# 0   Selection of Currencies   0000001
# 1   Selection of Currencies   0000053
# 2   Selection of Currencies   0000002
# 3   Selection of Currencies   0000003
# 4   Selection of Currencies   0000004
# 5   Selection of Currencies   0000005
# 6   Selection of Currencies   0000006
# 7   Selection of Currencies   0000007
# 8   Selection of Currencies   0000008
# 9   Selection of Currencies   0000009
# 10  Selection of Currencies   0000010
# 11  Selection of Currencies   0000011
# 12  Selection of Currencies   0000012
# 13  Selection of Currencies   0000013
# 14  Selection of Currencies   0000014
# 15  Selection of Currencies   0000017
# 16  Selection of Currencies   0000026
# 17  Selection of Currencies   0000027
# 18  Selection of Currencies   0000030
# 19  Selection of Currencies   0000015
# 20  Selection of Currencies   0000031
# 21  Selection of Currencies   0000032
# 22  Selection of Currencies   0000033
# 23  Selection of Currencies   0000028
# 24  Selection of Currencies   0000024
# 25  Selection of Currencies   0000029
# 26  Selection of Currencies   0000025
# 27  Selection of Currencies   0000034
# 28  Selection of Currencies   0000035
# 29  Selection of Currencies   0000036
# 30  Selection of Currencies   0000037
# 31  Selection of Currencies   0000038
# 32  Selection of Currencies   0000039
# 33  Selection of Currencies   0000040
# 34  Selection of Currencies   0000041
# 35  Selection of Currencies   0000042
# 36  Selection of Currencies   0000016
# 37  Selection of Currencies   0000018
# 38  Selection of Currencies   0000019
# 39  Selection of Currencies   0000043
# 40  Selection of Currencies   0000044
# 41  Selection of Currencies   0000045
# 42  Selection of Currencies   0000046
# 43  Selection of Currencies   0000020
# 44  Selection of Currencies   0000047
# 45  Selection of Currencies   0000048
# 46  Selection of Currencies   0000049
# 47  Selection of Currencies   0000021
# 48  Selection of Currencies   0000022
# 49  Selection of Currencies   0000023
# 50  Selection of Currencies   0000050
# 51  Selection of Currencies   0000051
# 52  Selection of Currencies   0000052
#
#                                             ITEM_NAME P_ITEM_CODE P_ITEM_NAME  \
# 0   Won per United States Dollar(Basic Exchange Rate)        None        None
# 1                   Won per Yuan(Basic Exchange Rate)        None        None
# 2                        Won per Japanese Yen(100Yen)        None        None
# 3                                        Won per Euro        None        None
# 4                                 Won per German Mark        None        None
# 5                                Won per French Franc        None        None
# 6                       Won per Italian Lira(100Lira)        None        None
# 7                               Won per Belgian Franc        None        None
# 8                          Won per Austrian Schilling        None        None
# 9                         Won per Netherlands Guilder        None        None
# 10                  Won per Spanish Peseta(100Peseta)        None        None
# 11                             Won per Finland Markka        None        None
# 12                       Won per United Kingdom Pound        None        None
# 13                            Won per Canadian Dollar        None        None
# 14                                Won per Swiss Franc        None        None
# 15                          Won per Australian Dollar        None        None
# 16                         Won per New Zealand Dollar        None        None
# 17               Won per Chinese Renminbi(China Yuan)        None        None
# 18           Won per Chinese Renminbi(Hong Kong Yuan)        None        None
# 19                            Won per Hongkong Dollar        None        None
# 20                           Won per Taiwanese Dollar        None        None
# 21                           Won per Mongolian Tugrik        None        None
# 22                           Won per Kazakhstan Tenge        None        None
# 23                                  Won per Thai Baht        None        None
# 24                           Won per Singapore Dollar        None        None
# 25                          Won per Indonesian Rupiah        None        None
# 26                          Won per Malaysian Ringgit        None        None
# 27                            Won per Philippine Peso        None        None
# 28                            Won per Vietnamese Dong        None        None
# 29                              Won per Brunei Dollar        None        None
# 30                               Won per Indian Rupee        None        None
# 31                            Won per Pakistani Rupee        None        None
# 32                            Won per Bangladesh Taka        None        None
# 33                               Won per Mexican Peso        None        None
# 34                             Won per Brazilian Real        None        None
# 35                             Won per Argentine Peso        None        None
# 36                               Won per Swdish Krona        None        None
# 37                               Won per Danish Krone        None        None
# 38                            Won per Norwagian Krone        None        None
# 39                              Won per Russian Ruble        None        None
# 40                           Won per Hungarian Forint        None        None
# 41                               Won per Polish Zloty        None        None
# 42                               Won per Czech Koruna        None        None
# 43                                Won per Saudi Riyal        None        None
# 44                               Won per Qatari Riyal        None        None
# 45                             Won per Israeli Shekel        None        None
# 46                            Won per Jordanian Dinar        None        None
# 47                              Won per Kuwaiti Dinar        None        None
# 48                             Won per Bahraini Dinar        None        None
# 49                Won per United Arab Emirates Dirham        None        None
# 50                               Won per Turkish Lira        None        None
# 51                         Won per South African Rand        None        None
# 52                             Won per Egyptian Pound        None        None
#
#    CYCLE START_TIME  END_TIME  DATA_CNT UNIT_NAME WEIGHT
# 0      D   19640504  20240806     16995       Won   None
# 1      D   20160104  20240806      2122       Won   None
# 2      D   19770401  20240806     13147       Won   None
# 3      D   19940411  20240806      8109       Won   None
# 4      D   19640504  20011231     11170       Won   None
# 5      D   19641214  20020216     10968       Won   None
# 6      D   19641214  20020228     10980       Won   None
# 7      D   19700220  20020228      9488       Won   None
# 8      D   19700220  20020228      9483       Won   None
# 9      D   19700220  20020128      9464       Won   None
# 10     D   19880104  20020228      4202       Won   None
# 11     D   19880104  20020228      4202       Won   None
# 12     D   19640504  20240806     16982       Won   None
# 13     D   19641214  20240806     16746       Won   None
# 14     D   19641214  20240806     16743       Won   None
# 15     D   19700220  20240806     15247       Won   None
# 16     D   19880104  20240806      9967       Won   None
# 17     D   19940411  20160201      6008       Won   None
# 18     D   20150102  20160308       250       Won   None
# 19     D   19640504  20240806     16924       Won   None
# 20     D   20150102  20240806      2371       Won   None
# 21     D   20150102  20240806      2371       Won   None
# 22     D   20150102  20240806      2371       Won   None
# 23     D   19940411  20240806      8109       Won   None
# 24     D   19830824  20240806     11260       Won   None
# 25     D   19940411  20240806      8109       Won   None
# 26     D   19830824  20240806     11260       Won   None
# 27     D   20150102  20240806      2371       Won   None
# 28     D   20150102  20240806      2371       Won   None
# 29     D   20150102  20240806      2371       Won   None
# 30     D   20150102  20240806      2371       Won   None
# 31     D   20150102  20240806      2371       Won   None
# 32     D   20150102  20240806      2371       Won   None
# 33     D   20150102  20240806      2371       Won   None
# 34     D   20150102  20240806      2371       Won   None
# 35     D   20150102  20240806      2371       Won   None
# 36     D   19670718  20240806     15970       Won   None
# 37     D   19700220  20240806     15252       Won   None
# 38     D   19700220  20240806     15254       Won   None
# 39     D   20150102  20240806      2371       Won   None
# 40     D   20150102  20240806      2371       Won   None
# 41     D   20150102  20240806      2371       Won   None
# 42     D   20150102  20240806      2371       Won   None
# 43     D   19760701  20240806     13373       Won   None
# 44     D   20150102  20240806      2371       Won   None
# 45     D   20150102  20240806      2371       Won   None
# 46     D   20150102  20240806      2371       Won   None
# 47     D   19770401  20240806     13148       Won   None
# 48     D   19770401  20240806     13149       Won   None
# 49     D   19770401  20240806     13149       Won   None
# 50     D   20150102  20240806      2371       Won   None
# 51     D   20150102  20240806      2371       Won   None
# 52     D   20150102  20240806      2371       Won   None

# %%
df = fetch_bok_data('StatisticItemList', stat_code = '731Y001')
# Out:
# https://ecos.bok.or.kr/api/StatisticItemList/IDI4QC444EYRWRBBQ8JN/json/en/1/100000/731Y001

# %% [markdown]
# We are interested in exchange rate between Korean Won (KRW) and US dollar (USD). So, we know that we are going to need `df.loc[0]`

# %% [markdown]
# ## **3. Fetch Item Values**

# %%
item = df.loc[0]

# %%
item
# Out:
# STAT_CODE                                                731Y001
# STAT_NAME      3.1.1.1. Arbitraged Rates of Major Currencies ...
# GRP_CODE                                                  Group1
# GRP_NAME                                 Selection of Currencies
# ITEM_CODE                                                0000001
# ITEM_NAME      Won per United States Dollar(Basic Exchange Rate)
# P_ITEM_CODE                                                 None
# P_ITEM_NAME                                                 None
# CYCLE                                                          D
# START_TIME                                              19640504
# END_TIME                                                20240806
# DATA_CNT                                                   16995
# UNIT_NAME                                                    Won
# WEIGHT                                                      None
# Name: 0, dtype: object

# %%
#This function is written in accordance with the devlopment specification of BOK API to fetch item values

def fetch_bok_data(service_code, stat_code = None, item = None):
    url = f'{BOK_API_URL}/{service_code}/{BOK_API_KEY}/json/en/1/100000' #10000 is sufficiently large, arbitrary number

    if item is not None:
        url += "/{}/{}/{}/{}/{}".format(

            item['STAT_CODE'], 
            item['CYCLE'],
            item['START_TIME'],
            item['END_TIME'],
            item['ITEM_CODE'],
        )
    
    elif stat_code:
        url += f'/{stat_code}' 
    
    print(url)
    resp = requests.get(url)
    results = resp.json()
    rows = results[service_code]['row']
    df = pd.DataFrame(rows)

    return df

# %%
fetch_bok_data('StatisticSearch', item = item)
# Out:
# https://ecos.bok.or.kr/api/StatisticSearch/IDI4QC444EYRWRBBQ8JN/json/en/1/100000/731Y001/D/19640504/20240806/0000001

# %%
df_xr = fetch_bok_data('StatisticSearch', item = item)

# %%
#take necessary columns only
df_xr = df_xr[['TIME', 'DATA_VALUE']]

# %% [markdown]
# > Fetching necessary data from BOK is done.\
# > Now, do whatever you are to do with the data!\
# > For example, we can start with the preprocessing of data we learned in our first class - 1. timestamp and 2. date-indexing

# %% [markdown]
# ### 1. Timestamp

# %%
df_xr.info()

# %%
df_xr['date'] = pd.to_datetime(df_xr['TIME'])

# %%
del df_xr['TIME']

# %% [markdown]
# ### 2. Date-indexing

# %%
df_xr = df_xr.set_index('date')

# %%
df_xr.head()

# %%
#naming the column
df_xr.columns = ['KRW/USD']

#type change
df_xr['KRW/USD'] = df_xr['KRW/USD'].astype(float)

# %%
df_xr
